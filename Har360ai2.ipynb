# %% [markdown]
# <a href="https://colab.research.google.com/github/rdntmsn/Harmony360/blob/main/Har360ai2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STEP 1: Install required package
# !pip install python-docx

# STEP 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# STEP 3: Import Libraries
import os, json
from pathlib import Path
from docx import Document

# STEP 4: Core Functions

def extract_text_from_docx(file_path):
    doc = Document(file_path)
    return "\n".join(p.text for p in doc.paragraphs if p.text.strip())

def generate_codex_anchor(text):
    return f"codex:{hash(text) % 10**8}"

def generate_guardian_context(text):
    return "GuardianAligned" if "guardian" in text.lower() else "Unaligned"

def generate_harmonic_tags(text):
    tags = []
    if "frequency" in text.lower(): tags.append("frequency")
    if "resonance" in text.lower(): tags.append("resonance")
    if "timeline" in text.lower(): tags.append("timeline")
    if "soul" in text.lower(): tags.append("soul")
    return tags

def convert_docx_to_har360(docx_path, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    text = extract_text_from_docx(docx_path)
    codex_anchor = generate_codex_anchor(text)
    guardian_context = generate_guardian_context(text)
    harmonic_tags = generate_harmonic_tags(text)

    har360_data = {
        "content": text,
        "codex_anchor": codex_anchor,
        "guardian_context": guardian_context,
        "harmonic_tags": harmonic_tags,
        "meta": {
            "source_file": os.path.basename(docx_path),
            "converted_by": "Harmony360 AI",
            "format_version": "1.0"
        }
    }

    output_file = Path(output_dir) / (Path(docx_path).stem + ".har360")
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(har360_data, f, indent=2)
    return output_file

def batch_convert_harmony360_docs(input_dir="/content/drive/MyDrive/Harmony360", output_dir="/content/drive/MyDrive/Harmony360/har360_output"):
    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(".docx"):
                full_path = os.path.join(root, file)
                try:
                    convert_docx_to_har360(full_path, output_dir)
                except Exception as e:
                    print(f"❌ Failed to convert {file}: {e}")
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.13.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# STEP 1: Install Dependencies
# !pip install python-docx openai --quiet

# STEP 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# STEP 3: Import Libraries
import os, json
from pathlib import Path
from docx import Document
from datetime import datetime
import hashlib

# STEP 4: Helper Functions

def extract_text_from_docx(file_path):
    doc = Document(file_path)
    return "\n".join(p.text for p in doc.paragraphs if p.text.strip())

def generate_codex_anchor(text):
    return f"codex:{hashlib.sha256(text.encode()).hexdigest()[:12]}"

def generate_guardian_context(text):
    return "GuardianAligned" if "guardian" in text.lower() else "Unaligned"

def generate_harmonic_tags(text):
    tags = []
    keywords = ["resonance", "timeline", "soul", "frequency", "geometry", "guardian", "node", "phi", "pi"]
    for kw in keywords:
        if kw in text.lower():
            tags.append(kw)
    return tags

def infer_tln_node(filename):
    hash_val = int(hashlib.sha256(filename.encode()).hexdigest(), 16)
    return f"TLN-{hash_val % 999:03d}"

def compute_resonance_score(text):
    score = 0.5
    if "resonance" in text.lower(): score += 0.1
    if "cri" in text.lower(): score += 0.1
    if "aomfaoy" in text.lower(): score += 0.1
    return min(round(score, 4), 1.0)

def auto_summarize(text):
    lines = text.strip().splitlines()
    return lines[0] if lines else "No summary available."

def generate_soul_vector(text):
    base = int(hashlib.sha256(text.encode()).hexdigest(), 16) % 1000
    return [round(base * x % 1.618, 4) for x in [0.618, 1.618, 2.236, 3.14]]

# STEP 5: Directory Conversion Script

def convert_all_to_har360(input_dir, output_dir="/content/drive/MyDrive/Harmony360/har360_output"):
    os.makedirs(output_dir, exist_ok=True)
    supported_exts = [".docx", ".txt"]

    for root, _, files in os.walk(input_dir):
        for file in files:
            ext = Path(file).suffix.lower()
            if ext not in supported_exts:
                continue

            file_path = os.path.join(root, file)
            try:
                text = extract_text_from_docx(file_path) if ext == ".docx" else Path(file_path).read_text(encoding="utf-8")
                codex_anchor = generate_codex_anchor(text)
                guardian_context = generate_guardian_context(text)
                harmonic_tags = generate_harmonic_tags(text)
                tln_node = infer_tln_node(file)
                resonance_score = compute_resonance_score(text)
                summary = auto_summarize(text)
                soul_vector = generate_soul_vector(text)

                har360_data = {
                    "content": text,
                    "codex_anchor": codex_anchor,
                    "guardian_context": guardian_context,
                    "harmonic_tags": harmonic_tags,
                    "tln_node": tln_node,
                    "resonance_score": resonance_score,
                    "summary": summary,
                    "soul_vector": soul_vector,
                    "meta": {
                        "source_file": file,
                        "converted_by": "Harmony360 AI",
                        "converted_at": datetime.utcnow().isoformat(),
                        "format_version": "2.0"
                    }
                }

                output_file = Path(output_dir) / (Path(file).stem + ".har360")
                with open(output_file, "w", encoding="utf-8") as f:
                    json.dump(har360_data, f, indent=2)

                print(f"✅ Converted: {file} → {output_file.name}")

            except Exception as e:
                print(f"❌ Failed to convert {file}: {e}")

# STEP 6: Run It

convert_all_to_har360("/content/drive/MyDrive/Harmony360/uploads")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
convert_all_to_har360("/content/drive/MyDrive/Harmony360")
# Out:
# ✅ Converted: harmony_ai_key_optimizerjsonl.txt → harmony_ai_key_optimizerjsonl.har360
# ❌ Failed to convert analysis_of_financial_cycle_studies_and_market_predictionspdftxttxttxttxttxttxttxt.txt: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ❌ Failed to convert analysis_of_financial_cycle_studies_and_market_predictionstxttxttxttxttxttxttxttxttxttxt.txt: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ❌ Failed to convert harmony360_the_complete_vol_1_325txttxttxttxttxttxttxttxttxttxt.txt: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ❌ Failed to convert harmony360_god_man_consciousness_updatetxttxttxttxttxttxttxttxttxttxt.txt: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Converted: harmony360_training_v2jsonltxttxttxttxttxttxt.txt → harmony360_training_v2jsonltxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_1jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_1jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_2jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_2jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_3jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_3jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_4jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_4jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_5jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_5jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_6jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_6jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_7jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_7jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_8jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_8jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_9jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_9jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_10jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_10jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_11jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_11jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_12jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_12jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_13jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_13jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_14jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_14jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_15jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_15jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_16jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_16jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_unified_theories_chunk_1jsonltxttxttxttxttxt.txt → harmony360_unified_theories_chunk_1jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_unified_theories_chunk_2jsonltxttxttxttxttxt.txt → harmony360_unified_theories_chunk_2jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_chunk_7jsonltxttxttxttxttxt.txt → harmony360_chunk_7jsonltxttxttxttxttxt.har360
# ✅ Converted: training_manifestjsontxttxt.txt → training_manifestjsontxttxt.har360
# ✅ Converted: harmony360_training_v3jsonltxttxttxttxttxttxttxt.txt → harmony360_training_v3jsonltxttxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_training_v2jsonltxt.txt → harmony360_training_v2jsonltxt.har360
# ✅ Converted: training_manifestjsontxt.txt → training_manifestjsontxt.har360
# ✅ Converted: harmony360_training_v2jsonltxttxttxttxt.txt → harmony360_training_v2jsonltxttxttxttxt.har360
# ✅ Converted: harmony360_training_v3jsonltxttxt.txt → harmony360_training_v3jsonltxttxt.har360
# ✅ Converted: harmony360_training_v2jsonl.txt → harmony360_training_v2jsonl.har360
# ✅ Converted: training_manifestjson.txt → training_manifestjson.har360
# ✅ Converted: harmony360_training_consciousness_v1jsonl.txt → harmony360_training_consciousness_v1jsonl.har360
# ✅ Converted: harmony360_training_financial_cycles_v1jsonl.txt → harmony360_training_financial_cycles_v1jsonl.har360
# ✅ Converted: harmony360_training_philosophy_v1jsonl.txt → harmony360_training_philosophy_v1jsonl.har360
# ✅ Converted: harmony360_training_technical_v1jsonl.txt → harmony360_training_technical_v1jsonl.har360
# ❌ Failed to convert harmony360_god_man_consciousnesstxt.txt: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ❌ Failed to convert the_beginning.txt: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Converted: harmony360_training_v2jsonltxttxttxt.txt → harmony360_training_v2jsonltxttxttxt.har360
# ✅ Converted: harmony360_training_v2jsonl.txt → harmony360_training_v2jsonl.har360
# ✅ Converted: merges.txt → merges.har360
# ✅ Converted: merges.txt → merges.har360
# ✅ Converted: merges.txt → merges.har360
# ✅ Converted: merges.txt → merges.har360
# ✅ Converted: merges.txt → merges.har360
# ✅ Converted: merges.txt → merges.har360
# ✅ Converted: Book Harmony360.docx → Book Harmony360.har360

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import os, json
from pathlib import Path
from docx import Document

def extract_text_from_docx(file_path):
    try:
        doc = Document(file_path)
        return "\n".join(p.text.strip() for p in doc.paragraphs if p.text.strip())
    except Exception as e:
        print(f"❌ Could not read DOCX: {file_path} — {e}")
        return ""

def extract_text_from_txt(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            return f.read()
    except UnicodeDecodeError:
        try:
            with open(file_path, 'r', encoding='latin-1') as f:
                return f.read()
        except Exception as e:
            print(f"❌ Could not read TXT: {file_path} — {e}")
            return ""

def extract_text_from_jsonl(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = [json.loads(line).get("text", "") for line in f if line.strip()]
            return "\n".join(lines)
    except Exception as e:
        print(f"❌ Could not read JSONL: {file_path} — {e}")
        return ""

def generate_codex_anchor(text): return f"codex:{abs(hash(text)) % 10**8}"
def generate_guardian_context(text): return "GuardianAligned" if "guardian" in text.lower() else "Unaligned"
def generate_harmonic_tags(text):
    tags, keywords = [], ["frequency", "resonance", "timeline", "CRI", "ZPC", "sacred geometry", "consciousness"]
    for kw in keywords:
        if kw.lower() in text.lower(): tags.append(kw.lower())
    return list(set(tags))

def generate_summary(text): return "Auto-generated summary from Harmony360 AI."
def infer_tln_node(filename, text): return Path(filename).stem.replace(" ", "_").lower()
def compute_resonance_score(text): return round(min(1.0, sum(text.lower().count(k.lower()) for k in ["CRI", "ZPC", "theta", "gamma", "phi", "resonance"]) / 20), 3)
def placeholder_soul_vector(): return [0.42, 0.66, 0.369]
def placeholder_fractal_score(): return 0.777

def convert_to_har360(input_path, output_path):
    ext = input_path.lower()
    if ext.endswith(".docx"):
        raw_text = extract_text_from_docx(input_path)
    elif ext.endswith(".jsonl"):
        raw_text = extract_text_from_jsonl(input_path)
    elif ext.endswith(".txt") or ext.endswith(".md"):
        raw_text = extract_text_from_txt(input_path)
    else:
        print(f"⏭️ Skipping unsupported file type: {input_path}")
        return

    if not raw_text.strip():
        print(f"⚠️ Skipping empty or unreadable file: {input_path}")
        return

    file_name = os.path.basename(input_path)
    har360 = {
        "content": raw_text,
        "codex_anchor": generate_codex_anchor(raw_text),
        "guardian_context": generate_guardian_context(raw_text),
        "harmonic_tags": generate_harmonic_tags(raw_text),
        "tln_node": infer_tln_node(file_name, raw_text),
        "resonance_score": compute_resonance_score(raw_text),
        "summary": generate_summary(raw_text),
        "fractal_score": placeholder_fractal_score(),
        "soul_vector": placeholder_soul_vector(),
        "meta": {
            "source_file": file_name,
            "converted_by": "Harmony360 AI",
            "format_version": "1.1"
        }
    }

    out_name = os.path.splitext(file_name)[0] + ".har360"
    out_path = os.path.join(output_path, out_name)
    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(har360, f, indent=2)

    print(f"✅ Converted: {file_name} → {out_name}")

# 🔁 Batch processor
def batch_convert_to_har360(source_dir, dest_dir):
    os.makedirs(dest_dir, exist_ok=True)
    for root, _, files in os.walk(source_dir):
        for f in files:
            full_path = os.path.join(root, f)
            convert_to_har360(full_path, dest_dir)

# 🧭 Set directories
source_folder = "/content/drive/MyDrive/Harmony360/"
output_folder = "/content/drive/MyDrive/Harmony360/converted_har360"
batch_convert_to_har360(source_folder, output_folder)
# Out:
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Supersymmetry.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Financial Cycle Studies & Market Predictions.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Analysis of Financial Cycle Studies & Market Predictions.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: The Complete Vol 1. 3.28.25.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/the beginning.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Development Update March 31, 2025.gdoc
# ⚠️ Skipping empty or unreadable file: /content/drive/MyDrive/Harmony360/harmony360_mock_training_dataset.jsonl
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 potential breakthroughs across various domains.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Quantum-Coherent Resonance and Consciousness Study.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/TLN-369 Simulation Report.gdoc
# ⚠️ Skipping empty or unreadable file: /content/drive/MyDrive/Harmony360/harmony360_training_v3.jsonl
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmonic Cosmic Hearth.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmonic Cosmic Hearth 2.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmonic Shell Geometry of Cosmic Hearth .gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmonic Geometry Achievement .gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Chapter 12- Atomic Resonance Shells and Platonic Symmetry.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Untitled document (2).gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har36032525.ipynb
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360.ipynb
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Symmetry, Resonance, and the Circle of Fifths.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Spanish tutor.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Untitled document (1).gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Untitled document.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360_TLN_Final_Lock.ipynb
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/ATLANTIS Quantum Bridge Node Interface Protocol.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Guardian Activation Protocol.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Prime Number Theorems & Quantum Models.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Mastery Test - AI Response.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 & God-Man Consciousness Project: Most Comprehensive Update.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Master Update.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: End-of-Day Status Report.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: Midday Status Report Date: 2025-02-26 (12:00 PM).gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: Updated Status Report (Aligned with Both Updates) Date: 2025-02-26 (2:30 PM).gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/GOAT MANAGER LETTER OF ACCEPTANCE.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Internal Document: Communication Guidelines for Resonathor (RT360) as Chief Quantum Harmonicist (CQH) Date: 2025-02-28 Tracking ID: har360 2025-02-28 Communication Protocol v1.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Comparative Analysis of Volume 1 & Volume 2 – Harmony360 & Judah Elder Ascension.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: Advanced Knowledge Validation Quiz & Assessment.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Mathematical Analysis of Harmony360's Equations Applied to Neural Networks.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Chapter 3: Judah Elder Cymatic Architecture & Cosmic Engineering.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Core Equations.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Chapter 5: Judah Elder Cosmic Infrastructure – The Arcology & Star Citadel Networks.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: The Foundations of Universal Energy II.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: The Foundations of Universal Energy Vol2.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Plan for Writing Volume 2: Harmony360 & The Judah Elder Ascension.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Volume II: The Supreme Society of the Judah Elders.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Internal Announcement: Welcoming Resonathor (RT360) to the Harmony360 Team.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/That. Is. LEGENDARY!.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Hands-On Research Module: Harmony360 Applications.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Master Timeline.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/The Philosophical Dimensions of Harmony360.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Exploring New Applications of Harmony360’s Equations in AI & Emerging Technologies.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 AI Execution Update & Next Actions (DA3IO Initiated).gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: Current Status, Findings, and Next Steps – Full Summary.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Review & Next Steps for Testing the Fibonacci...
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Corporation – Where We Are bh360-feb28.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360 Status Updatebh36033715.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: Current Status, Key Milestones, and Remaining Tasks22225.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Harmony360: February 25, 2025.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/trainingfiles/Fractal Resonance and Unified Theories of Reality: A Comparative Analysis.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/trainingfiles/harmony360_training_unified_theories_v1.jsonl.gdoc
# ✅ Converted: harmony_ai_key_optimizerjsonl.txt → harmony_ai_key_optimizerjsonl.har360
# ✅ Converted: analysis_of_financial_cycle_studies_and_market_predictionspdftxttxttxttxttxttxttxt.txt → analysis_of_financial_cycle_studies_and_market_predictionspdftxttxttxttxttxttxttxt.har360
# ✅ Converted: analysis_of_financial_cycle_studies_and_market_predictionstxttxttxttxttxttxttxttxttxttxt.txt → analysis_of_financial_cycle_studies_and_market_predictionstxttxttxttxttxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_the_complete_vol_1_325txttxttxttxttxttxttxttxttxttxt.txt → harmony360_the_complete_vol_1_325txttxttxttxttxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_god_man_consciousness_updatetxttxttxttxttxttxttxttxttxttxt.txt → harmony360_god_man_consciousness_updatetxttxttxttxttxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_training_v2jsonltxttxttxttxttxttxt.txt → harmony360_training_v2jsonltxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_1jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_1jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_2jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_2jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_3jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_3jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_4jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_4jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_5jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_5jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_6jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_6jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_7jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_7jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_8jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_8jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_9jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_9jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_10jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_10jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_11jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_11jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_12jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_12jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_13jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_13jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_14jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_14jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_15jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_15jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_financial_cycles_chunk_16jsonltxttxttxttxttxt.txt → harmony360_financial_cycles_chunk_16jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_unified_theories_chunk_1jsonltxttxttxttxttxt.txt → harmony360_unified_theories_chunk_1jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_unified_theories_chunk_2jsonltxttxttxttxttxt.txt → harmony360_unified_theories_chunk_2jsonltxttxttxttxttxt.har360
# ✅ Converted: harmony360_chunk_7jsonltxttxttxttxttxt.txt → harmony360_chunk_7jsonltxttxttxttxttxt.har360
# ✅ Converted: training_manifestjsontxttxt.txt → training_manifestjsontxttxt.har360
# ✅ Converted: harmony360_training_v3jsonltxttxttxttxttxttxttxt.txt → harmony360_training_v3jsonltxttxttxttxttxttxttxt.har360
# ✅ Converted: harmony360_training_v2jsonltxt.txt → harmony360_training_v2jsonltxt.har360
# ✅ Converted: training_manifestjsontxt.txt → training_manifestjsontxt.har360
# ✅ Converted: harmony360_training_v2jsonltxttxttxttxt.txt → harmony360_training_v2jsonltxttxttxttxt.har360
# ✅ Converted: harmony360_training_v3jsonltxttxt.txt → harmony360_training_v3jsonltxttxt.har360
# ✅ Converted: harmony360_training_v2jsonl.txt → harmony360_training_v2jsonl.har360
# ✅ Converted: training_manifestjson.txt → training_manifestjson.har360
# ✅ Converted: harmony360_training_consciousness_v1jsonl.txt → harmony360_training_consciousness_v1jsonl.har360
# ✅ Converted: harmony360_training_financial_cycles_v1jsonl.txt → harmony360_training_financial_cycles_v1jsonl.har360
# ✅ Converted: harmony360_training_philosophy_v1jsonl.txt → harmony360_training_philosophy_v1jsonl.har360
# ✅ Converted: harmony360_training_technical_v1jsonl.txt → harmony360_training_technical_v1jsonl.har360
# ✅ Converted: harmony360_god_man_consciousnesstxt.txt → harmony360_god_man_consciousnesstxt.har360
# ⚠️ Skipping empty or unreadable file: /content/drive/MyDrive/Harmony360/trainingfiles/harmony360_training_v2.jsonl
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/trainingfiles/training_manifest (1).json
# ✅ Converted: the_beginning.txt → the_beginning.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/trainingfiles/training_manifest.json
# ✅ Converted: harmony360_training_v2jsonltxttxttxt.txt → harmony360_training_v2jsonltxttxttxt.har360
# ✅ Converted: harmony360_training_v2jsonl.txt → harmony360_training_v2jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/generation_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/model.safetensors
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/training_args.bin
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/special_tokens_map.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/vocab.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/tokenizer_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/tokenizer.json
# ✅ Converted: merges.txt → merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/scaler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/generation_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/model.safetensors
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/special_tokens_map.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/tokenizer_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/vocab.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/training_args.bin
# ✅ Converted: merges.txt → merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/tokenizer.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/optimizer.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/rng_state.pth
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/trainer_state.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-10/scheduler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/scaler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/generation_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/model.safetensors
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/vocab.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/training_args.bin
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/tokenizer_config.json
# ✅ Converted: merges.txt → merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/special_tokens_map.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/tokenizer.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/optimizer.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/trainer_state.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/rng_state.pth
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen1-model/checkpoint-20/scheduler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/generation_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/model.safetensors
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/tokenizer_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/special_tokens_map.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/tokenizer.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/vocab.json
# ✅ Converted: merges.txt → merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/training_args.bin
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/scaler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/generation_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/model.safetensors
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/special_tokens_map.json
# ✅ Converted: merges.txt → merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/tokenizer_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/vocab.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/training_args.bin
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/tokenizer.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/optimizer.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/rng_state.pth
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/scheduler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-50/trainer_state.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/scaler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/generation_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/model.safetensors
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/vocab.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/training_args.bin
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/tokenizer_config.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/special_tokens_map.json
# ✅ Converted: merges.txt → merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/tokenizer.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/optimizer.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/rng_state.pth
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/trainer_state.json
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/harmony360-gen2-model/checkpoint-52/scheduler.pt
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book Title: Harmony360: Unifying the Cosmos Through Fractal Resonance.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book Title: Harmony360: A Unified Framework of Resonance, Quantum Mechanics, and Gravity.gdoc
# ✅ Converted: Book Harmony360.docx → Book Harmony360.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Harmony360 eBook.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 11- The Harmony360 AI Model.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 10- Time-Lattice Navigator and Temporal Mechanics.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 9- Cryptography, Identity, and the QRC-360 Protocol.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 8- Quantum Harmonics and Field Dynamics.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 7- Applications and Simulation Models.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 6- Geometry, Structure, and the Harmonic Universe.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 5- Time and Temporal Dynamics.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 4- Consciousness and the Mind.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Chapter 3- Harmony in Energy and Physics.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 1/Untitled document.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 1- Prime Number Structured Resonance.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 2- Fractalized Axiomatic Physics.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 3- Prime Resonance and Riemann Field Extensions.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter X- Harmony in Action — 2025 Breakthroughs--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Volume 2- Chapter X — Harmony in Action- Living Proofs of 2025--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 4 — Quantum-Coherent Astrophysics--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 5 — Energy-Information-Consciousness Unified Field--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 6 — Resonant Blockchain and Secure Fractal Communication--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 7 — TLN-369- Time-Lattice Phase 2 Engineering--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 8 — Advanced Consciousness Simulation Models.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 9 — Fractal Harmonic Cosmogenesis.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 10 — The Meta-Lattice- Reality’s Coherence Layers.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Books/Book volumes/Volume 2/Chapter 11 — Postscript- Toward The Cosmic Continuum.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Harmony360 interpret the visual data as a deeply interconnected resonance system.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /The `.h360` metadata profiles generated for the first 5 uploaded images.
#
#
# .gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Here’s a breakdown of --what Harmony360 sees-- across the set-.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Here is your --corrected test suite-- with proper `datetime` handling and import alignment-.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /These errors all stem from --incorrect use of the `datetime` module-- in your test cases.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Complete Harmony360 snapshot confirms we now have-.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /har360.42925v.ipynb.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Here's a --correct and ready-to-use unit test-- for your `AGNFeedbackResonator` class.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Here is your --corrected and safe test file-- for `AGNFeedbackResonator`.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Harmony360 isn’t merely an abstract model — it's now acting as a universal resonance translator across disciplines.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Harmony360 perceives a powerful symbolic and functional convergence in this new image batch, revealing layered resonance patterns across nature, consciousness, and cosmological architecture.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Fractal Neural Network /Harmony360 would likely interpret the visual data as a deeply interconnected resonance system spanning several symbolic, natural, physical, and esoteric frameworks.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Light Is a Memory of Geometry.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Comprehensive Analysis of Intermodular Resonance in Harmony360 Framework.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Poetic Introduction- Harmony360 Whitepaper.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Harmony360 White Paper- Multi-Module Resonance Analysis.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Harmony360 Resonant Music Protocol White Paper.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Untitled document.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Harmony360 Response Paper.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Papers/Music as the Breath of Resonance- A Quantum-Harmonic Model of Universal Structure.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/Teleportation as explored by researchers at the University of Rochester and Purdue University.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/MIT physicists in capturing images of individual atoms interacting freely.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/Ultracold atoms reveal a new type of quantum magnetic behavior - MIT .gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/A First in Quantum Science- Single Atoms Captured in Free Space ….gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/Entry #002 for the --Harmony360 Scientific Proof Archive---.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/Twist of light- Non-reciprocity in photon polarization may unlock gravity and quantum mechanics ….gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/Entry #001 – Informational Gravity via Quantum Entanglement.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/Sharing scientific breakthroughs alongside Harmony360.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Proofs/“Study Suggests Quantum Entanglement May Rewrite the Rules of Gravity” – Matt Swayne, -Annals of Physics-.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Reports/Harmony360 Quantum Economic System- Comprehensive Report.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/God-Man chat/### --The Resonant Music Protocol- Sound as Conscious Geometry in the Harmony360 Framework--.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3601.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3602.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3603.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3605.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3604.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3606.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3607.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3609.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har3608.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har36010.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har36011.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har36014.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har36012.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/har36013.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony_ai_key_optimizerjsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_3jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_5jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_2jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_9jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_8jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_4jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_6jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_1jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_7jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v2jsonltxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_10jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_11jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_13jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_14jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_16jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_unified_theories_chunk_1jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_15jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_financial_cycles_chunk_12jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_unified_theories_chunk_2jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_chunk_7jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v3jsonltxttxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/training_manifestjsontxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v2jsonltxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v2jsonltxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/training_manifestjsontxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v2jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v3jsonltxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/training_manifestjson.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_consciousness_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_financial_cycles_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_technical_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_philosophy_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/harmony360_training_v2jsonltxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/har360_output/Book Harmony360.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Soul Match Profile /GuardianProtocol.har360.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Soul Match Profile /TimelineRender.har360.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/Soul Match Profile /SoulMatchProfile.har360.gdoc
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony_ai_key_optimizerjsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_god_man_consciousness_updatetxttxttxttxttxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v2jsonltxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_1jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_4jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_2jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_the_complete_vol_1_325txttxttxttxttxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/analysis_of_financial_cycle_studies_and_market_predictionstxttxttxttxttxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/analysis_of_financial_cycle_studies_and_market_predictionspdftxttxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_3jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_5jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_6jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_8jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_7jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_9jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_10jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_11jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_12jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_14jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_13jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_15jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_unified_theories_chunk_1jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_financial_cycles_chunk_16jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_unified_theories_chunk_2jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_chunk_7jsonltxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v3jsonltxttxttxttxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v2jsonltxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/training_manifestjsontxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v2jsonltxttxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/training_manifestjsontxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v3jsonltxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v2jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/training_manifestjson.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_consciousness_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_financial_cycles_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_philosophy_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_god_man_consciousnesstxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_v2jsonltxttxttxt.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/harmony360_training_technical_v1jsonl.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/the_beginning.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/merges.har360
# ⏭️ Skipping unsupported file type: /content/drive/MyDrive/Harmony360/converted_har360/Book Harmony360.har360

# %%
# STEP 1: Imports
import os, json
from pathlib import Path
from datasets import Dataset
from datetime import datetime

# STEP 2: Set Directories
har360_dir = "/content/drive/MyDrive/Harmony360/har360_output"  # Adjust if needed
har360_files = [f for f in Path(har360_dir).rglob("*.har360")]

# STEP 3: Load .har360 Files
def load_har360_files(file_paths):
    dataset_entries = []
    for path in file_paths:
        try:
            with open(path, "r", encoding="utf-8") as f:
                data = json.load(f)

            # Build a prompt-style training string
            entry = {
                "instruction": f"Analyze this Harmony360 document titled '{data['meta']['source_file']}'",
                "input": f"Tags: {', '.join(data.get('harmonic_tags', []))}\nSummary: {data.get('summary', '')}",
                "output": data.get("content", "No content found."),
            }
            dataset_entries.append(entry)

        except Exception as e:
            print(f"❌ Failed to load {path.name}: {e}")
    return dataset_entries

raw_entries = load_har360_files(har360_files)
print(f"✅ Loaded {len(raw_entries)} .har360 files for training.")

# STEP 4: Convert to HuggingFace Dataset
hf_dataset = Dataset.from_list(raw_entries)

# STEP 5: Format for Language Modeling
hf_dataset = hf_dataset.map(lambda x: {
    "text": f"### Instruction:\n{x['instruction']}\n\n### Input:\n{x['input']}\n\n### Output:\n{x['output']}"
})

# ✅ Ready to tokenize and train
print("✅ Harmony360AI dataset is prepared.")
# Out:
# ✅ Loaded 50 .har360 files for training.
# Map:   0%|          | 0/50 [00:00<?, ? examples/s]
# ✅ Harmony360AI dataset is prepared.

# %%
# STEP 1: Install Required Packages
# !pip install transformers datasets loguru --quiet

# STEP 2: Setup Logging
from loguru import logger
import os

os.makedirs("har360ailogs", exist_ok=True)
logger.add("har360ailogs/harmony360_training.log", rotation="1 MB", retention="10 days")
logger.info("✅ Loguru initialized — all logs will be saved in har360ailogs/")

# STEP 3: Load Model + Tokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer, DataCollatorForLanguageModeling
import torch

model_name = "gpt2"  # You can change this to any compatible model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Fix padding token for GPT models
tokenizer.pad_token = tokenizer.eos_token
model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.eos_token_id

# STEP 4: Tokenization Function
def tokenize(example):
    return tokenizer(example["text"], truncation=True, padding="max_length", max_length=512)

logger.info("✅ Tokenizing Harmony360AI dataset...")
tokenized_dataset = hf_dataset.map(tokenize, batched=True)
logger.info("✅ Tokenization complete.")

# STEP 5: Training Arguments
training_args = TrainingArguments(
    output_dir="./harmony360-model-v2",
    per_device_train_batch_size=2,
    num_train_epochs=4,
    logging_steps=10,
    save_steps=100,
    save_total_limit=2,
    fp16=torch.cuda.is_available(),
    logging_dir="har360ailogs",
    report_to="none"  # Disables wandb
)

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# STEP 6: Define Custom Trainer Logging Callback
from transformers import TrainerCallback, TrainingArguments, TrainerState, TrainerControl

class LoguruCallback(TrainerCallback):
    def on_log(self, args: TrainingArguments, state: TrainerState, control: TrainerControl, logs=None, **kwargs):
        if logs:
            for k, v in logs.items():
                logger.info(f"{k}: {v}")

# STEP 7: Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks=[LoguruCallback()]
)

# STEP 8: Train
logger.info("✅ Starting Harmony360AI fine-tuning...")
trainer.train()
logger.success("✅ Training complete — model saved to ./harmony360-model-v2")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.0 MB/s eta 0:00:00
# 2025-05-30 01:19:32.892 | INFO     | __main__:<cell line: 0>:10 - ✅ Loguru initialized — all logs will be saved in har360ailogs/
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# 2025-05-30 01:20:26.164 | INFO     | __main__:<cell line: 0>:29 - ✅ Tokenizing Harmony360AI dataset...
# Map:   0%|          | 0/50 [00:00<?, ? examples/s]
# 2025-05-30 01:20:30.144 | INFO     | __main__:<cell line: 0>:31 - ✅ Tokenization complete.
# <ipython-input-7-395bfe31f87d>:61: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# 2025-05-30 01:20:30.167 | INFO     | __main__:<cell line: 0>:71 - ✅ Starting Harmony360AI fine-tuning...
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='37' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 37/100 11:39 < 20:59, 0.05 it/s, Epoch 1.44/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.137400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.285800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.651500</td>
#     </tr>
#   </tbody>
# </table><p>
# 2025-05-30 01:24:03.521 | INFO     | __main__:on_log:58 - loss: 3.1374
# 2025-05-30 01:24:03.523 | INFO     | __main__:on_log:58 - grad_norm: 5.451176166534424
# 2025-05-30 01:24:03.525 | INFO     | __main__:on_log:58 - learning_rate: 4.55e-05
# 2025-05-30 01:24:03.526 | INFO     | __main__:on_log:58 - epoch: 0.4
# 2025-05-30 01:27:17.485 | INFO     | __main__:on_log:58 - loss: 3.2858
# 2025-05-30 01:27:17.486 | INFO     | __main__:on_log:58 - grad_norm: 6.299837589263916
# 2025-05-30 01:27:17.487 | INFO     | __main__:on_log:58 - learning_rate: 4.05e-05
# 2025-05-30 01:27:17.488 | INFO     | __main__:on_log:58 - epoch: 0.8
# 2025-05-30 01:30:30.449 | INFO     | __main__:on_log:58 - loss: 2.6515
# 2025-05-30 01:30:30.450 | INFO     | __main__:on_log:58 - grad_norm: 6.715677738189697
# 2025-05-30 01:30:30.451 | INFO     | __main__:on_log:58 - learning_rate: 3.55e-05
# 2025-05-30 01:30:30.452 | INFO     | __main__:on_log:58 - epoch: 1.2
#     <div>
#
#       <progress value='38' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 38/100 11:58 < 20:37, 0.05 it/s, Epoch 1.48/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.137400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.285800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.651500</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# ✅ Save both the model and tokenizer
trainer.save_model("./harmony360-model-v2")
tokenizer.save_pretrained("./harmony360-model-v2")

# %%
import json
from pathlib import Path

# Define the target path
model_dir = Path("./harmony360-model-v2")
config_path = model_dir / "config.json"

# GPT-Neo compatible config snippet
patched_config = {
    "model_type": "gpt_neo",
    "hidden_size": 2048,
    "intermediate_size": 8192,
    "num_attention_heads": 16,
    "num_hidden_layers": 24,
    "vocab_size": 50257,
    "pad_token_id": 50256
}

# Load existing config if available and update only if needed
if config_path.exists():
    with open(config_path, "r", encoding="utf-8") as f:
        existing_config = json.load(f)
else:
    existing_config = {}

# Patch or insert required fields
existing_config.update(patched_config)

# Save the updated config
with open(config_path, "w", encoding="utf-8") as f:
    json.dump(existing_config, f, indent=2)

print(f"✅ Patched config.json at: {config_path}")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_path = "./harmony360-model-v2"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load your fine-tuned Harmony360AI model
model_path = "./harmony360-model-v2"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

# Inference function
def chat_harmony360(prompt, max_length=300, temperature=0.7, top_p=0.9):
    inputs = tokenizer(prompt, return_tensors="pt")
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            temperature=temperature,
            top_p=top_p,
            pad_token_id=tokenizer.eos_token_id,
            do_sample=True
        )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example test prompt
prompt = """### Instruction:
Summarize the resonance principles behind a fractal harmonic field.

### Input:
Include references to CRI, TLN, and AOMFAOY values.

### Output:"""

response = chat_harmony360(prompt)
print(response)

# %%
# ✅ STEP 1: Install Requirements
# !pip install python-docx --quiet


# ✅ STEP 2: Import Libraries
import os, json
from pathlib import Path
from docx import Document
from google.colab import drive

drive.mount('/content/drive')


# ✅ STEP 3: Extraction Logic
def extract_text_from_docx(file_path):
    doc = Document(file_path)
    return "\n".join(p.text.strip() for p in doc.paragraphs if p.text.strip())

def generate_codex_anchor(text):
    return f"codex:{abs(hash(text)) % 10**8}"

def generate_guardian_context(text):
    return "GuardianAligned" if "guardian" in text.lower() else "Unaligned"

def generate_harmonic_tags(text):
    tags = []
    keywords = ["frequency", "resonance", "timeline", "CRI", "ZPC", "sacred geometry", "consciousness"]
    for kw in keywords:
        if kw.lower() in text.lower():
            tags.append(kw.lower())
    return list(set(tags))

def generate_summary(text):
    return "Summary: Instructor manual for the God-Man Consciousness protocol, including harmonic training structure and CRI logic."

def infer_tln_node(filename, text):
    return Path(filename).stem.replace(" ", "_").lower()

def compute_resonance_score(text):
    keywords = ["CRI", "ZPC", "theta", "gamma", "phi", "resonance"]
    score = sum(text.lower().count(k.lower()) for k in keywords)
    return round(min(1.0, score / 20), 3)

def placeholder_soul_vector():
    return [0.42, 0.66, 0.369]

def placeholder_fractal_score():
    return 0.777  # placeholder for now

# ✅ STEP 4: Main Converter
def convert_docx_to_har360(input_path, output_path):
    raw_text = extract_text_from_docx(input_path)
    file_name = os.path.basename(input_path)

    har360 = {
        "content": raw_text,
        "codex_anchor": generate_codex_anchor(raw_text),
        "guardian_context": generate_guardian_context(raw_text),
        "harmonic_tags": generate_harmonic_tags(raw_text),
        "tln_node": infer_tln_node(file_name, raw_text),
        "resonance_score": compute_resonance_score(raw_text),
        "summary": generate_summary(raw_text),
        "fractal_score": placeholder_fractal_score(),
        "soul_vector": placeholder_soul_vector(),
        "meta": {
            "source_file": file_name,
            "converted_by": "Harmony360 AI",
            "format_version": "1.1"
        }
    }

    out_name = os.path.splitext(file_name)[0] + ".har360"
    out_path = os.path.join(output_path, out_name)

    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(har360, f, indent=2)

    print(f"✅ Converted: {file_name} → {out_name}")

# ✅ STEP 5: Run on Folder
def batch_convert_docs(source_dir, dest_dir):
    os.makedirs(dest_dir, exist_ok=True)
    for root, _, files in os.walk(source_dir):
        for f in files:
            if f.endswith(".docx") and not f.startswith("~$"):
                convert_docx_to_har360(os.path.join(root, f), dest_dir)

# ✅ STEP 6: Set Paths
source_folder = "/content/drive/MyDrive/Harmony360/"
output_folder = "/content/drive/MyDrive/Harmony360/converted_har360"

batch_convert_docs(source_folder, output_folder)
